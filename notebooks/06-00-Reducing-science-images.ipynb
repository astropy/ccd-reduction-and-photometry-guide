# %% [markdown]
# # Редукция science изображений

# %% [markdown]
# Материал в предыдущих главах был направлен на калибровку science изображений. Скомбинированные изображения bias, dark и flat из предыдущих шагов используются для калибровки изображений любого интересующего объекта, находящегося на science изображениях.
