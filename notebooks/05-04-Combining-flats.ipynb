# %% [markdown]
# # Комбинирование flat-кадров
#
# Есть один шаг в комбинировании flat-кадров, который отличается от большинства
# других комбинаций изображений: flat-кадры должны быть масштабированы к
# общему значению перед их комбинированием. Это особенно важно, если flat-кадры
# — это twilight flat, в которых среднее значение изображения обычно существенно
# изменяется по мере получения изображений.
#
# Flat-кадры обычно группируются по фильтру при их комбинировании. То есть один
# комбинированный flat производится для каждого фильтра, в котором были получены
# flat-кадры.
#
# Комбинирование будет проведено для каждого из двух примеров в предыдущем
# блокноте.

# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import ccdproc as ccdp
from astropy.stats import mad_std
from astropy.visualization import hist

from convenience_functions import show_image

# %%
# Use custom style for larger fonts and figures
plt.style.use('guide.mplstyle')

# %% [markdown]
# ## Пример 1
#
# Начнём с настройки коллекции изображений для уменьшенных данных. Эти данные
# получены с чипа 0 криогенно охлаждаемой Large Format Camera в обсерватории
# Паломар.

# %%
calibrated_path = Path('example1-reduced')

flat_imagetyp = 'flatfield'

ifc = ccdp.ImageFileCollection(calibrated_path)

# %% [markdown]
# Сначала проверим, какие фильтры присутствуют.

# %%
flat_filters = set(h['filter'] for h in ifc.headers(imagetyp=flat_imagetyp))
flat_filters

# %% [markdown]
# Эти flat-кадры — dome flat, по сути снимки экрана в куполе, освещённые
# источником света, поэтому вы не ожидали бы большие вариации в типичном
# значении пикселя между разными экспозициями. Обычно есть *какая-то*
# вариация, но мы нанесём её на график ниже.

# %%
median_count = [np.median(data) for data in ifc.data(imagetyp=flat_imagetyp)]
mean_count = [np.mean(data) for data in ifc.data(imagetyp=flat_imagetyp)]
plt.plot(median_count, label='median')
plt.plot(mean_count, label='mean')
plt.xlabel('Image number')
plt.ylabel('Count (ADU)')
plt.title('Pixel value in calibrated flat frames')
plt.legend()
print(median_count)

# %% [markdown]
# Хотя это меньше вариаций кадр-за-кадром, чем мы увидим в примере 2, это около
# 5%. Если бы мы комбинировали эти без масштабирования flat-кадров к общему
# значению, то изображения с более высокими отсчётами будут иметь больший вес,
# чем изображения.
#
# Есть существенная разница между средним и медианой этих данных. Обычно лучше
# использовать медиану, потому что экстремальные значения не влияют на медиану
# так сильно, как на среднее значение.
#
# Чтобы масштабировать кадры так, чтобы они имели одно и то же значение медианы,
# нам нужно определить функцию, которая может вычислить обратное значение
# медианы по данным.

# %%
def inv_median(a):
    return 1 / np.median(a)

# %% [markdown]
# Эта функция передаётся в аргумент `scale` функции `combine` ниже. Один
# комбинированный flat создаётся для каждого фильтра в данных.

# %%
for filt in flat_filters:
    to_combine = ifc.files_filtered(imagetyp=flat_imagetyp, filter=filt, include_path=True)
    combined_flat = ccdp.combine(to_combine,
                                 method='average', scale=inv_median,
                                 sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                 sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std,
                                 mem_limit=350e6
                                )

    combined_flat.meta['combined'] = True
    dark_file_name = 'combined_flat_filter_{}.fit'.format(filt.replace("''", "p"))
    combined_flat.write(calibrated_path / dark_file_name)

# %% [markdown]
# ### Discussion of Example 1

# %% [markdown]
# ### Обсуждение примера 1

# %%
ifc.refresh()
ifc.files_filtered(imagetyp=flat_imagetyp, combined=True)

# %% [markdown]
# Начнём с проверки того, что создано правильное количество комбинированных
# flat-кадров. Было два фильтра, `g'` и `i'` в сырых данных, поэтому должно быть
# два комбинированных flat-кадра. Нам нужно обновить `ImageFileCollection` для
# уменьшенных данных, потому что в них были добавлены новые файлы, наши flat-кадры.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 20), tight_layout=True)

for ccd, axis in zip(ifc.ccds(imagetyp=flat_imagetyp, combined=True), axes):
    show_image(ccd.data, cmap='gray', fig=fig, ax=axis)
    title = "Filter {}".format(ccd.header['filter'])
    axis.set_title(title)

# %% [markdown]
# Это выглядит хорошо. Два flat-кадра отображены ниже.

# %% [markdown]
# Первое, что нужно заметить — flat-кадры отличаются в этих двух фильтрах. Это
# ожидается, потому что один из элементов в оптическом пути, фильтр, отличается.
#
# Паттерн электроники в flat-кадрах — потому что это backside-illuminated CCD.
# Пиксели, обнаруживающие свет, находятся на нижней стороне чипа, и свет должен
# пройти через чип, чтобы достичь датчика. Маленькие тёмные пятна — это места,
# где чип не был одинаково тонким.
#
# Сравните это с [примером 2](#обсуждение-примера-2) ниже, который показывает
# flat-кадр, полученный с frontside-illuminated камерой.

# %%
calibrated_path = Path('example2-reduced')

flat_imagetyp = 'flat'

ifc = ccdp.ImageFileCollection(calibrated_path)

# %%
flat_filters = set(h['filter'] for h in ifc.headers(imagetyp=flat_imagetyp))
flat_filters

# %% [markdown]
# Twilight flat-кадры обычно отличаются больше кадр-за-кадром, чем dome flat,
# как показано на рисунке ниже.

# %%
median_count = [np.median(hdu.data) for hdu in ifc.hdus(imagetyp=flat_imagetyp)]
mean_count = [np.mean(data) for data in ifc.data(imagetyp=flat_imagetyp)]
plt.plot(median_count, label='median')
plt.plot(mean_count, label='mean')
plt.xlabel('Image number')
plt.ylabel('Count (ADU)')
plt.title('Pixel value in calibrated flat frames')
plt.legend()
print(median_count)

# %%
def inv_median(a):
    return 1 / np.median(a)

for filt in flat_filters:
    to_combine = ifc.files_filtered(imagetyp=flat_imagetyp, filter=filt, include_path=True)
    combined_flat = ccdp.combine(to_combine,
                                 method='average', scale=inv_median,
                                 sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                 sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std,
                                 mem_limit=350e6
                                )

    combined_flat.meta['combined'] = True
    dark_file_name = 'combined_flat_filter_{}.fit'.format(filt.replace("''", "p"))
    combined_flat.write(calibrated_path / dark_file_name)

# %% [markdown]
# ### Discussion of Example 2

# %% [markdown]
# Мы ожидаем только один комбинированный flat, потому что был только один фильтр.
# `ImageFileCollection` обновляется перед запросом, потому что комбинированные
# flat-кадры были добавлены после создания коллекции.

# %%
ifc.refresh()
ifc.files_filtered(imagetyp=flat_imagetyp, combined=True)

# %% [markdown]
# Комбинированный flat отображён ниже.

# %%
show_image(combined_flat, cmap='gray', figsize=(10, 20))

# %% [markdown]
# Этот flat выглядит очень по-другому, чем тот в [примере 1](#обсуждение-примера-1),
# потому что этот CCD — frontside-illuminated и предыдущий — backside-illuminated.
# Это значит, что датчик находится сверху чипа, и свет не должен проходить через
# чип датчика, чтобы достичь датчиков. Хотя здесь показан только один фильтр,
# flat field выглядит немного по-другому через другие фильтры на этой камере.
